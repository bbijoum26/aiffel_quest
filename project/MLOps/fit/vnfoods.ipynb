# %% [markdown]
# # 베트남 음식 분류하기
#
# 데이터셋: [30VNFoods](https://www.kaggle.com/datasets/quandang/vietnamese-foods)
# - 30가지 베트남 음식 이미지를 모아놓은 것
# - Banh xeo, Pho 등 다양한 이미지들이 있다.
#
# ![image.png](attachment:image.png)
#
# 30종류의 베트남 음식 중 10개의 카테고리를 선별해 실습을 진행할 예정이다.
#
#
# **평가문항**
# 1. 주어진 함수들과 TensorFlow Data API를 이용해서 dataloader를 구현했다.
#     - dataloader를 만드는 과정이 에러 없이 수행되었다
# 2. 베트남 음식 사진 분류를 위한 모델을 구현했다.
#     - EfficientNetB0 backbone과 Dense 레이어를 결합하여 모델을 성공적으로 구현했다.
# 3. TensorFlow GradientTape을 이용해서 custom trainer 클래스를 구현했다.
#     - 학습이 진행되면서 training accuracy가 점차 증가하였다.

# %%
import os
import pathlib
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### 손상된 이미지 파일 삭제

# %%
print(os.getcwd()) # 현재 작업 디렉토리 출력
# Out:
# /aiffel/aiffel/vnfoods

# %%
data_path = '/aiffel/aiffel/vnfoods/data/30vnfoods/'
train_path = data_path + 'Train/'
test_path = data_path + 'Test/'

# %%
for path in [train_path, test_path]:
    classes = os.listdir(path)

    for food in classes:
        food_path = os.path.join(path, food)
        images = os.listdir(food_path)
        
        for image in images:
            with open(os.path.join(food_path, image), 'rb') as f:
                bytes = f.read()
            if bytes[:3] != b'\xff\xd8\xff':
                print(os.path.join(food_path, image))
                os.remove(os.path.join(food_path, image))
# Out:
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh cuon/88.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh cuon/781.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh cuon/26.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh cuon/634.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh cuon/45.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh cuon/677.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh cuon/350.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh mi/860.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh mi/623.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun dau mam tom/351.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun dau mam tom/175.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Chao long/86.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun rieu/647.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun rieu/106.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun rieu/758.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun rieu/89.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun rieu/325.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Com tam/258.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Com tam/497.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Com tam/569.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Com tam/481.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh xeo/403.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh xeo/307.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh xeo/196.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh xeo/428.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh xeo/318.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh xeo/820.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh xeo/118.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh khot/24.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Banh khot/84.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Pho/613.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Pho/125.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Pho/273.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun bo Hue/1530.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun bo Hue/427.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun bo Hue/643.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun bo Hue/785.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Train/Bun bo Hue/502.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Test/Banh cuon/719.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Test/Banh cuon/470.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Test/Bun rieu/822.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Test/Com tam/283.jpg
# /aiffel/aiffel/vnfoods/data/30vnfoods/Test/Com tam/681.jpg

# %% [markdown]
# ### 삭제되고 난 후의 훈련 데이터 수

# %%
classes = os.listdir(train_path)
train_length = 0

for food in classes:
    food_path = os.path.join(train_path, food)
    images = os.listdir(food_path)
    
    train_length += len(images)

print('training data의 개수: '+str(train_length))
# Out:
# training data의 개수: 9775

# %% [markdown]
# ## 해결할 문제

# %% [markdown]
# ### 문제1: dataloader 구현하기
# 주어진 함수들과 TensorFlow Data API를 이용해서 dataloader 구현

# %% [markdown]
# #### `process_path` 함수
# - file_path로 부터 class label을 만들고, 이미지를 읽는 함수
# - 이미지 크기를 (224, 224)로 맞춘다.

# %%
def process_path(file_path, class_names, img_shape=(224, 224)):
    label = tf.strings.split(file_path, os.path.sep)
    label = label[-2] == class_names

    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, img_shape)
    return img, label

# %% [markdown]
# #### `prepare_for_training` 함수
# TensorFlow Data API를 이용해 data batch를 만드는 함수

# %%
def prepare_for_training(ds, batch_size=32, cache=True, shuffle_buffer_size=1000):
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat(1000)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

    return ds

# %% [markdown]
# #### `load_data` 함수
# - 데이터를 만들기 위해 필요한 함수들을 호출하고 데이터를 리턴해주는 함수
# - TensorFlow Dataset 객체를 생성하고 process_path 함수로 이미지와 라벨을 묶은 다음,
# - prepare_for_training 함수로 batch가 적용된 Dataset 객체를 만들준다.

# %%
def load_data(data_path, batch_size=32):
    class_names = [cls for cls in os.listdir(data_path) if cls != '.DS_Store']
    data_path = pathlib.Path(data_path)

    list_ds = tf.data.Dataset.list_files(str(data_path/'*/*'))
    labeled_ds = list_ds.map(lambda x: process_path(x, class_names, img_shape=(224, 224)))
    ds = prepare_for_training(labeled_ds, batch_size=batch_size)

    return ds

# %% [markdown]
# ### 문제2: 모델 구현하기
# - EfficientNetB0 backbone과 Dense 레이어를 결합하여 모델 구현
#     - Classification 문제로 접근할 것이기 때문에 맨 마지막 Dense 레이어에 우리가 원하는 클래스 개수만큼을 지정해 준다.
# - 다른 방법: 다른 모델을 사용하여 backbone 구현

# %%
from tensorflow.keras.applications import EfficientNetB0

class Model(tf.keras.Model):

    def __init__(self, num_classes=5, freeze=False):
        super(Model, self).__init__()
        self.base_model = EfficientNetB0(include_top=False, weights='imagenet')
        if freeze:
            self.base_model.trainable = False
        self.top = tf.keras.Sequential([tf.keras.layers.GlobalAveragePooling2D(name="avg_pool"),
                                       tf.keras.layers.BatchNormalization(),
                                       tf.keras.layers.Dropout(0.5, name="top_dropout")])
        self.classifier = tf.keras.layers.Dense(num_classes, activation="softmax", name="pred")

    def call(self, inputs, training=True):
        x = self.base_model(inputs)
        x = self.top(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ### 문제3: custom trainer 구현하기
# - TensorFlow GradientTape를 이용해서 custom trainer 클래스 구현
# - 학습이 진행되면서 training accuracy가 점차 증가할 수 있도록 한다.

# %%
class Trainer:
    
    def __init__(self, model, epochs, batch, ds_length, loss_fn, optimizer):
        self.model = model
        self.epochs = epochs
        self.batch = batch
        self.ds_length = ds_length
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        
    def train(self, train_dataset, train_metric):
        for epoch in range(self.epochs):
            print("\nStart of epoch %d" % (epoch+1,))
            # 매 batch 마다 반복적으로 학습
            for step, (x_batch_train, y_batch_train) in enumerate(train_dataset):
                with tf.GradientTape() as tape:
                    logits = model(x_batch_train, training=True)
                    loss_value = self.loss_fn(y_batch_train, logits)
                grads = tape.gradient(loss_value, model.trainable_weights)
                self.optimizer.apply_gradients(zip(grads, model.trainable_weights))
                # train metric 업데이트
                train_metric.update_state(y_batch_train, logits)
                # 5 배치마다 로깅
                if step % 5 == 0:
                    print(
                        "Training loss (for one batch) at step %d: %.4f"
                        % (step, float(loss_value))
                    )
                    print("Seen so far: %d samples" % ((step + 1) * self.batch))
                    print(train_metric.result().numpy())

            # 마지막 epoch 학습이 끝나면 train 결과를 보여줌
            train_acc = train_acc_metric.result()
            print("Training acc over epoch: %.4f" % (float(train_acc),))

# %% [markdown]
# ### 모델 학습

# %%
train_path = "/aiffel/aiffel/vnfoods/data/30vnfoods/Train"

epoch = 10
batch = 16

model = Model(num_classes=10)
dataset = load_data(data_path=train_path, batch_size=batch)
loss_function = tf.keras.losses.CategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()
train_acc_metric = tf.keras.metrics.CategoricalAccuracy()
trainer = Trainer(model=model,
                epochs=epoch,
                batch=batch,
                ds_length=train_length,
                loss_fn=loss_function,
                optimizer=optimizer)

trainer.train(train_dataset=dataset,
            train_metric=train_acc_metric)
# Out:
# Start of epoch 1
# Training loss (for one batch) at step 0: 4.2520
# Seen so far: 16 samples
# 0.0
# Training loss (for one batch) at step 5: 2.9466
# Seen so far: 96 samples
# 0.15625
# Training loss (for one batch) at step 10: 3.1226
# Seen so far: 176 samples
# 0.2215909
# Training loss (for one batch) at step 15: 2.8298
# Seen so far: 256 samples
# 0.2421875
# Training loss (for one batch) at step 20: 1.8093
# Seen so far: 336 samples
# 0.2827381
# Training loss (for one batch) at step 25: 2.1559
# Seen so far: 416 samples
# 0.3221154
# Training loss (for one batch) at step 30: 1.1919
# Seen so far: 496 samples
# 0.3467742
# Training loss (for one batch) at step 35: 3.4917
# Seen so far: 576 samples
# 0.36458334
# Training loss (for one batch) at step 40: 2.3134
# Seen so far: 656 samples
# 0.3871951
# Training loss (for one batch) at step 45: 2.0515
# Seen so far: 736 samples
# 0.4035326
# Training loss (for one batch) at step 50: 1.7643
# Seen so far: 816 samples
# 0.41911766
# Training loss (for one batch) at step 55: 1.6483
# Seen so far: 896 samples
# 0.42745537
# Training loss (for one batch) at step 60: 2.3870
# Seen so far: 976 samples
# 0.43954918
# Training loss (for one batch) at step 65: 1.9763
# Seen so far: 1056 samples
# 0.45075756
# Training loss (for one batch) at step 70: 1.4889
# Seen so far: 1136 samples
# 0.465669
# Training loss (for one batch) at step 75: 1.0863
# Seen so far: 1216 samples
# 0.47944078
# Training loss (for one batch) at step 80: 2.3946
# Seen so far: 1296 samples
# 0.49305555
# Training loss (for one batch) at step 85: 1.3559
# Seen so far: 1376 samples
# 0.502907
# Training loss (for one batch) at step 90: 1.4724
# Seen so far: 1456 samples
# 0.5082418
# Training loss (for one batch) at step 95: 1.1575
# Seen so far: 1536 samples
# 0.51692706
# Training loss (for one batch) at step 100: 1.5397
# Seen so far: 1616 samples
# 0.5247525
# Training loss (for one batch) at step 105: 0.6057
# Seen so far: 1696 samples
# 0.5318396
# Training loss (for one batch) at step 110: 1.6761
# Seen so far: 1776 samples
# 0.536036
# Training loss (for one batch) at step 115: 1.2883
# Seen so far: 1856 samples
# 0.5436422
# Training loss (for one batch) at step 120: 1.0999
# Seen so far: 1936 samples
# 0.5495868
# Training loss (for one batch) at step 125: 1.0781
# Seen so far: 2016 samples
# 0.55456346
# Training loss (for one batch) at step 130: 0.9897
# Seen so far: 2096 samples
# 0.5610687
# Training loss (for one batch) at step 135: 1.1672
# Seen so far: 2176 samples
# 0.5661765
# Training loss (for one batch) at step 140: 1.9464
# Seen so far: 2256 samples
# 0.5678192
# Training loss (for one batch) at step 145: 0.7000
# Seen so far: 2336 samples
# 0.5706336
# Training loss (for one batch) at step 150: 1.7150
# Seen so far: 2416 samples
# 0.5740894
# Training loss (for one batch) at step 155: 0.4956
# Seen so far: 2496 samples
# 0.5793269
# Training loss (for one batch) at step 160: 0.5477
# Seen so far: 2576 samples
# 0.58229816
# Training loss (for one batch) at step 165: 2.0837
# Seen so far: 2656 samples
# 0.58320785
# Training loss (for one batch) at step 170: 1.7204
# Seen so far: 2736 samples
# 0.5873538
# Training loss (for one batch) at step 175: 1.5282
# Seen so far: 2816 samples
# 0.5901989
# Training loss (for one batch) at step 180: 1.3624
# Seen so far: 2896 samples
# 0.5908149
# Training loss (for one batch) at step 185: 0.1909
# Seen so far: 2976 samples
# 0.5957661
# Training loss (for one batch) at step 190: 0.0882
# Seen so far: 3056 samples
# 0.5998037
# Training loss (for one batch) at step 195: 0.4933
# Seen so far: 3136 samples
# 0.6039541
# Training loss (for one batch) at step 200: 0.7726
# Seen so far: 3216 samples
# 0.60541046
# Training loss (for one batch) at step 205: 0.9793
# Seen so far: 3296 samples
# 0.6074029
# Training loss (for one batch) at step 210: 1.4258
# Seen so far: 3376 samples
# 0.6098934
# Training loss (for one batch) at step 215: 1.5826
# Seen so far: 3456 samples
# 0.6108218
# Training loss (for one batch) at step 220: 0.6648
# Seen so far: 3536 samples
# 0.613405
# Training loss (for one batch) at step 225: 1.1284
# Seen so far: 3616 samples
# 0.61725664
# Training loss (for one batch) at step 230: 1.2237
# Seen so far: 3696 samples
# 0.6176948
# Training loss (for one batch) at step 235: 1.2921
# Seen so far: 3776 samples
# 0.61996824
# Training loss (for one batch) at step 240: 0.6897
# Seen so far: 3856 samples
# 0.62162864
# Training loss (for one batch) at step 245: 1.4246
# Seen so far: 3936 samples
# 0.6229675
# Training loss (for one batch) at step 250: 0.3461
# Seen so far: 4016 samples
# 0.624253
# Training loss (for one batch) at step 255: 1.2139
# Seen so far: 4096 samples
# 0.6262207
# Training loss (for one batch) at step 260: 1.4644
# Seen so far: 4176 samples
# 0.62811303
# Training loss (for one batch) at step 265: 0.5400
# Seen so far: 4256 samples
# 0.6299342
# Training loss (for one batch) at step 270: 2.1608
# Seen so far: 4336 samples
# 0.63238007
# Training loss (for one batch) at step 275: 0.7610
# Seen so far: 4416 samples
# 0.6333786
# Training loss (for one batch) at step 280: 0.4594
# Seen so far: 4496 samples
# 0.6352313
# Training loss (for one batch) at step 285: 0.8267
# Seen so far: 4576 samples
# 0.6383304
# Training loss (for one batch) at step 290: 0.8410
# Seen so far: 4656 samples
# 0.6387457
# Training loss (for one batch) at step 295: 0.6527
# Seen so far: 4736 samples
# 0.6404139
# Training loss (for one batch) at step 300: 0.6260
# Seen so far: 4816 samples
# 0.64244187
# Training loss (for one batch) at step 305: 0.7852
# Seen so far: 4896 samples
# 0.6433824
# Training loss (for one batch) at step 310: 1.1892
# Seen so far: 4976 samples
# 0.6432878
# Training loss (for one batch) at step 315: 0.4247
# Seen so far: 5056 samples
# 0.6455696
# Training loss (for one batch) at step 320: 0.6709
# Seen so far: 5136 samples
# 0.64719623
# Training loss (for one batch) at step 325: 2.1726
# Seen so far: 5216 samples
# 0.64723927
# Training loss (for one batch) at step 330: 0.4870
# Seen so far: 5296 samples
# 0.6489804
# Training loss (for one batch) at step 335: 0.0930
# Seen so far: 5376 samples
# 0.65066963
# Training loss (for one batch) at step 340: 1.8596
# Seen so far: 5456 samples
# 0.65249264
# Training loss (for one batch) at step 345: 0.9988
# Seen so far: 5536 samples
# 0.65408236
# Training loss (for one batch) at step 350: 0.6422
# Seen so far: 5616 samples
# 0.65544873
# Training loss (for one batch) at step 355: 0.0497
# Seen so far: 5696 samples
# 0.65677667
# Training loss (for one batch) at step 360: 0.6461
# Seen so far: 5776 samples
# 0.658241
# Training loss (for one batch) at step 365: 0.5758
# Seen so far: 5856 samples
# 0.6594945
# Training loss (for one batch) at step 370: 0.6265
# Seen so far: 5936 samples
# 0.66004044
# Training loss (for one batch) at step 375: 1.5118
# Seen so far: 6016 samples
# 0.66073805
# Training loss (for one batch) at step 380: 0.7881
# Seen so far: 6096 samples
# 0.66190946
# Training loss (for one batch) at step 385: 0.7801
# Seen so far: 6176 samples
# 0.6628886
# Training loss (for one batch) at step 390: 0.4773
# Seen so far: 6256 samples
# 0.66432226
# Training loss (for one batch) at step 395: 1.0197
# Seen so far: 6336 samples
# 0.6649306
# Training loss (for one batch) at step 400: 0.5548
# Seen so far: 6416 samples
# 0.6666147
# Training loss (for one batch) at step 405: 0.9585
# Seen so far: 6496 samples
# 0.66871923
# Training loss (for one batch) at step 410: 1.0099
# Seen so far: 6576 samples
# 0.6703163
# Training loss (for one batch) at step 415: 1.6931
# Seen so far: 6656 samples
# 0.6711238
# Training loss (for one batch) at step 420: 0.9083
# Seen so far: 6736 samples
# 0.67206055
# Training loss (for one batch) at step 425: 1.4085
# Seen so far: 6816 samples
# 0.6732688
# Training loss (for one batch) at step 430: 0.5927
# Seen so far: 6896 samples
# 0.675029
# Training loss (for one batch) at step 435: 0.4008
# Seen so far: 6976 samples
# 0.6761755
# Training loss (for one batch) at step 440: 0.5957
# Seen so far: 7056 samples
# 0.67687076
# Training loss (for one batch) at step 445: 1.6427
# Seen so far: 7136 samples
# 0.6768498
# Training loss (for one batch) at step 450: 1.2250
# Seen so far: 7216 samples
# 0.6775222
# Training loss (for one batch) at step 455: 1.0869
# Seen so far: 7296 samples
# 0.6781798
# Training loss (for one batch) at step 460: 0.9231
# Seen so far: 7376 samples
# 0.67868763
# Training loss (for one batch) at step 465: 0.7954
# Seen so far: 7456 samples
# 0.67851394
# Training loss (for one batch) at step 470: 1.1049
# Seen so far: 7536 samples
# 0.67914015
# Training loss (for one batch) at step 475: 0.8478
# Seen so far: 7616 samples
# 0.67949057
# Training loss (for one batch) at step 480: 0.8823
# Seen so far: 7696 samples
# 0.68087316
# Training loss (for one batch) at step 485: 1.1630
# Seen so far: 7776 samples
# 0.681713
# Training loss (for one batch) at step 490: 0.3292
# Seen so far: 7856 samples
# 0.68240833
# Training loss (for one batch) at step 495: 0.5108
# Seen so far: 7936 samples
# 0.6827117
# Training loss (for one batch) at step 500: 0.8026
# Seen so far: 8016 samples
# 0.683508
# Training loss (for one batch) at step 505: 0.2649
# Seen so far: 8096 samples
# 0.6850296
# Training loss (for one batch) at step 510: 0.7369
# Seen so far: 8176 samples
# 0.68554306
# Training loss (for one batch) at step 515: 0.6107
# Seen so far: 8256 samples
# 0.6864099
# Training loss (for one batch) at step 520: 0.2485
# Seen so far: 8336 samples
# 0.6871401
# Training loss (for one batch) at step 525: 1.1030
# Seen so far: 8416 samples
# 0.68773764
# Training loss (for one batch) at step 530: 0.8102
# Seen so far: 8496 samples
# 0.68844163
# Training loss (for one batch) at step 535: 0.2765
# Seen so far: 8576 samples
# 0.68913245
# Training loss (for one batch) at step 540: 1.0620
# Seen so far: 8656 samples
# 0.689695
# Training loss (for one batch) at step 545: 0.8881
# Seen so far: 8736 samples
# 0.6904762
# Training loss (for one batch) at step 550: 0.2959
# Seen so far: 8816 samples
# 0.6912432
# Training loss (for one batch) at step 555: 0.4115
# Seen so far: 8896 samples
# 0.6921088
# Training loss (for one batch) at step 560: 0.0915
# Seen so far: 8976 samples
# 0.69262475
# Training loss (for one batch) at step 565: 0.2668
# Seen so far: 9056 samples
# 0.69368374
# Training loss (for one batch) at step 570: 0.5016
# Seen so far: 9136 samples
# 0.69483364
# Training loss (for one batch) at step 575: 0.6368
# Seen so far: 9216 samples
# 0.695855
# Training loss (for one batch) at step 580: 0.8815
# Seen so far: 9296 samples
# 0.696321
# Training loss (for one batch) at step 585: 0.5200
# Seen so far: 9376 samples
# 0.697099
# Training loss (for one batch) at step 590: 1.0069
# Seen so far: 9456 samples
# 0.6974408
# Training loss (for one batch) at step 595: 0.6028
# Seen so far: 9536 samples
# 0.6983012
# Training loss (for one batch) at step 600: 1.8040
# Seen so far: 9616 samples
# 0.6990433
# Training loss (for one batch) at step 605: 0.7620
# Seen so far: 9696 samples
# 0.69936055
# Training loss (for one batch) at step 610: 0.6714
# Seen so far: 9776 samples
# 0.699775
# Training loss (for one batch) at step 615: 0.5950
# Seen so far: 9856 samples
# 0.70109576
# Training loss (for one batch) at step 620: 1.0225
# Seen so far: 9936 samples
# 0.7015902
# Training loss (for one batch) at step 625: 0.5604
# Seen so far: 10016 samples
# 0.7023762
# Training loss (for one batch) at step 630: 0.3380
# Seen so far: 10096 samples
# 0.7032488
# Training loss (for one batch) at step 635: 1.5297
# Seen so far: 10176 samples
# 0.7034198
# Training loss (for one batch) at step 640: 1.1873
# Seen so far: 10256 samples
# 0.70368564
# Training loss (for one batch) at step 645: 0.5585
# Seen so far: 10336 samples
# 0.7048181
# Training loss (for one batch) at step 650: 0.2789
# Seen so far: 10416 samples
# 0.70593315
# Training loss (for one batch) at step 655: 0.6570
# Seen so far: 10496 samples
# 0.70674545
# Training loss (for one batch) at step 660: 0.6401
# Seen so far: 10576 samples
# 0.7075454
# Training loss (for one batch) at step 665: 0.3434
# Seen so far: 10656 samples
# 0.7088026
# Training loss (for one batch) at step 670: 0.2687
# Seen so far: 10736 samples
# 0.70957524
# Training loss (for one batch) at step 675: 0.2939
# Seen so far: 10816 samples
# 0.710429
# Training loss (for one batch) at step 680: 0.9075
# Seen so far: 10896 samples
# 0.71108663
# Training loss (for one batch) at step 685: 1.1983
# Seen so far: 10976 samples
# 0.7119169
# Training loss (for one batch) at step 690: 1.8775
# Seen so far: 11056 samples
# 0.7126447
# Training loss (for one batch) at step 695: 0.4524
# Seen so far: 11136 samples
# 0.71318245
# Training loss (for one batch) at step 700: 1.7966
# Seen so far: 11216 samples
# 0.7133559
# Training loss (for one batch) at step 705: 0.0449
# Seen so far: 11296 samples
# 0.7140581
# Training loss (for one batch) at step 710: 0.2829
# Seen so far: 11376 samples
# 0.71475035
# Training loss (for one batch) at step 715: 0.6156
# Seen so far: 11456 samples
# 0.71552026
# Training loss (for one batch) at step 720: 1.7375
# Seen so far: 11536 samples
# 0.7156727
# Training loss (for one batch) at step 725: 1.1168
# Seen so far: 11616 samples
# 0.7165117
# Training loss (for one batch) at step 730: 1.3103
# Seen so far: 11696 samples
# 0.7171683
# Training loss (for one batch) at step 735: 0.2756
# Seen so far: 11776 samples
# 0.71798575
# Training loss (for one batch) at step 740: 1.0187
# Seen so far: 11856 samples
# 0.71887654
# Training loss (for one batch) at step 745: 0.0790
# Seen so far: 11936 samples
# 0.71975535
# Training loss (for one batch) at step 750: 0.3855
# Seen so far: 12016 samples
# 0.7205393
# Training loss (for one batch) at step 755: 0.2449
# Seen so far: 12096 samples
# 0.7213955
# Training loss (for one batch) at step 760: 0.4578
# Seen so far: 12176 samples
# 0.7221584
# Training loss (for one batch) at step 765: 0.3954
# Seen so far: 12256 samples
# 0.72274804
# Training loss (for one batch) at step 770: 0.7507
# Seen so far: 12336 samples
# 0.72292477
# Training loss (for one batch) at step 775: 1.3371
# Seen so far: 12416 samples
# 0.7235019
# Training loss (for one batch) at step 780: 1.1257
# Seen so far: 12496 samples
# 0.72367156
# Training loss (for one batch) at step 785: 0.2047
# Seen so far: 12576 samples
# 0.72423667
# Training loss (for one batch) at step 790: 0.6192
# Seen so far: 12656 samples
# 0.7249526
# Training loss (for one batch) at step 795: 0.5246
# Seen so far: 12736 samples
# 0.7258166
# Training loss (for one batch) at step 800: 0.4827
# Seen so far: 12816 samples
# 0.7262797
# Training loss (for one batch) at step 805: 0.7796
# Seen so far: 12896 samples
# 0.7266594
# Training loss (for one batch) at step 810: 0.1813
# Seen so far: 12976 samples
# 0.7274969
# Training loss (for one batch) at step 815: 1.4088
# Seen so far: 13056 samples
# 0.7277114
# Training loss (for one batch) at step 820: 0.4965
# Seen so far: 13136 samples
# 0.7279233
# Training loss (for one batch) at step 825: 0.3109
# Seen so far: 13216 samples
# 0.7288136
# Training loss (for one batch) at step 830: 0.3146
# Seen so far: 13296 samples
# 0.72961795
# Training loss (for one batch) at step 835: 0.9795
# Seen so far: 13376 samples
# 0.7305622
# Training loss (for one batch) at step 840: 1.1539
# Seen so far: 13456 samples
# 0.7309007
# Training loss (for one batch) at step 845: 0.0645
# Seen so far: 13536 samples
# 0.7319001
# Training loss (for one batch) at step 850: 0.6600
# Seen so far: 13616 samples
# 0.7322268
# Training loss (for one batch) at step 855: 0.3301
# Seen so far: 13696 samples
# 0.73298776
# Training loss (for one batch) at step 860: 0.7790
# Seen so far: 13776 samples
# 0.73359466
# Training loss (for one batch) at step 865: 0.5925
# Seen so far: 13856 samples
# 0.73383373
# Training loss (for one batch) at step 870: 0.5462
# Seen so far: 13936 samples
# 0.73457235
# Training loss (for one batch) at step 875: 0.4073
# Seen so far: 14016 samples
# 0.7350171
# Training loss (for one batch) at step 880: 0.7272
# Seen so far: 14096 samples
# 0.73538595
# Training loss (for one batch) at step 885: 0.4541
# Seen so far: 14176 samples
# 0.7359622
# Training loss (for one batch) at step 890: 0.1252
# Seen so far: 14256 samples
# 0.7364618
# Training loss (for one batch) at step 895: 0.2570
# Seen so far: 14336 samples
# 0.7370257
# Training loss (for one batch) at step 900: 1.1585
# Seen so far: 14416 samples
# 0.73786074
# Training loss (for one batch) at step 905: 0.1593
# Seen so far: 14496 samples
# 0.7382726
# Training loss (for one batch) at step 910: 0.3638
# Seen so far: 14576 samples
# 0.7388858
# Training loss (for one batch) at step 915: 1.2099
# Seen so far: 14656 samples
# 0.73887825
# Training loss (for one batch) at step 920: 0.3597
# Seen so far: 14736 samples
# 0.73927796
# Training loss (for one batch) at step 925: 0.4127
# Seen so far: 14816 samples
# 0.73960584
# Training loss (for one batch) at step 930: 0.9789
# Seen so far: 14896 samples
# 0.73993015
# Training loss (for one batch) at step 935: 0.3224
# Seen so far: 14976 samples
# 0.74005073
# Training loss (for one batch) at step 940: 0.2613
# Seen so far: 15056 samples
# 0.7405685
# Training loss (for one batch) at step 945: 0.8601
# Seen so far: 15136 samples
# 0.7408166
# Training loss (for one batch) at step 950: 0.1457
# Seen so far: 15216 samples
# 0.7416535
# Training loss (for one batch) at step 955: 0.1519
# Seen so far: 15296 samples
# 0.74228555
# Training loss (for one batch) at step 960: 0.6262
# Seen so far: 15376 samples
# 0.74265087
# Training loss (for one batch) at step 965: 0.2514
# Seen so far: 15456 samples
# 0.7430124
# Training loss (for one batch) at step 970: 1.1817
# Seen so far: 15536 samples
# 0.74298406
# Training loss (for one batch) at step 975: 0.7294
# Seen so far: 15616 samples
# 0.7432761
# Training loss (for one batch) at step 980: 0.4958
# Seen so far: 15696 samples
# 0.74369264
# Training loss (for one batch) at step 985: 1.4682
# Seen so far: 15776 samples
# 0.74435854
# Training loss (for one batch) at step 990: 0.8862
# Seen so far: 15856 samples
# 0.7446393
# Training loss (for one batch) at step 995: 1.2701
# Seen so far: 15936 samples
# 0.74510545
# Training loss (for one batch) at step 1000: 0.3331
# Seen so far: 16016 samples
# 0.74544203
# Training loss (for one batch) at step 1005: 1.0605
# Seen so far: 16096 samples
# 0.74571323
# Training loss (for one batch) at step 1010: 0.5263
# Seen so far: 16176 samples
# 0.7460435
# Training loss (for one batch) at step 1015: 0.9891
# Seen so far: 16256 samples
# 0.7466782
# Training loss (for one batch) at step 1020: 0.2092
# Seen so far: 16336 samples
# 0.7473678
# Training loss (for one batch) at step 1025: 0.5041
# Seen so far: 16416 samples
# 0.74750245
# Training loss (for one batch) at step 1030: 0.0962
# Seen so far: 16496 samples
# 0.748242
# Training loss (for one batch) at step 1035: 0.1474
# Seen so far: 16576 samples
# 0.74861246
# Training loss (for one batch) at step 1040: 0.3101
# Seen so far: 16656 samples
# 0.7487392
# Training loss (for one batch) at step 1045: 0.4644
# Seen so far: 16736 samples
# 0.7491037
# Training loss (for one batch) at step 1050: 0.5755
# Seen so far: 16816 samples
# 0.74952424
# Training loss (for one batch) at step 1055: 1.0496
# Seen so far: 16896 samples
# 0.7496449
# Training loss (for one batch) at step 1060: 1.2957
# Seen so far: 16976 samples
# 0.7497055
# Training loss (for one batch) at step 1065: 0.3532
# Seen so far: 17056 samples
# 0.75005865
# Training loss (for one batch) at step 1070: 0.2224
# Seen so far: 17136 samples
# 0.750817
# Training loss (for one batch) at step 1075: 0.4158
# Seen so far: 17216 samples
# 0.75092936
# Training loss (for one batch) at step 1080: 1.2222
# Seen so far: 17296 samples
# 0.7513876
# Training loss (for one batch) at step 1085: 0.5881
# Seen so far: 17376 samples
# 0.7519567
# Training loss (for one batch) at step 1090: 0.4423
# Seen so far: 17456 samples
# 0.7525206
# Training loss (for one batch) at step 1095: 0.4909
# Seen so far: 17536 samples
# 0.7529083
# Training loss (for one batch) at step 1100: 0.7016
# Seen so far: 17616 samples
# 0.7528383
# Training loss (for one batch) at step 1105: 0.4684
# Seen so far: 17696 samples
# 0.7533341
# Training loss (for one batch) at step 1110: 0.5439
# Seen so far: 17776 samples
# 0.75337535
# Training loss (for one batch) at step 1115: 1.1726
# Seen so far: 17856 samples
# 0.75375223
# Training loss (for one batch) at step 1120: 0.2033
# Seen so far: 17936 samples
# 0.7541258
# Training loss (for one batch) at step 1125: 2.8025
# Seen so far: 18016 samples
# 0.75421846
# Training loss (for one batch) at step 1130: 1.1894
# Seen so far: 18096 samples
# 0.7540893
# Training loss (for one batch) at step 1135: 0.5529
# Seen so far: 18176 samples
# 0.7541813
# Training loss (for one batch) at step 1140: 0.2802
# Seen so far: 18256 samples
# 0.7544369
# Training loss (for one batch) at step 1145: 0.4746
# Seen so far: 18336 samples
# 0.7547993
# Training loss (for one batch) at step 1150: 0.1976
# Seen so far: 18416 samples
# 0.75494134
# Training loss (for one batch) at step 1155: 1.6692
# Seen so far: 18496 samples
# 0.7548118
# Training loss (for one batch) at step 1160: 0.1908
# Seen so far: 18576 samples
# 0.7552218
# Training loss (for one batch) at step 1165: 0.6234
# Seen so far: 18656 samples
# 0.75541383
# Training loss (for one batch) at step 1170: 0.3705
# Seen so far: 18736 samples
# 0.75587106
# Training loss (for one batch) at step 1175: 0.6530
# Seen so far: 18816 samples
# 0.75616497
# Training loss (for one batch) at step 1180: 0.5417
# Seen so far: 18896 samples
# 0.7563506
# Training loss (for one batch) at step 1185: 0.7852
# Seen so far: 18976 samples
# 0.7563765
# Training loss (for one batch) at step 1190: 0.4103
# Seen so far: 19056 samples
# 0.756717
# Training loss (for one batch) at step 1195: 0.9417
# Seen so far: 19136 samples
# 0.75695026
# Training loss (for one batch) at step 1200: 0.7714
# Seen so far: 19216 samples
# 0.7573376
# Training loss (for one batch) at step 1205: 0.6991
# Seen so far: 19296 samples
# 0.75767
# Training loss (for one batch) at step 1210: 0.6961
# Seen so far: 19376 samples
# 0.75789636
# Training loss (for one batch) at step 1215: 0.1328
# Seen so far: 19456 samples
# 0.75837785
# Training loss (for one batch) at step 1220: 0.8506
# Seen so far: 19536 samples
# 0.7586507
# Training loss (for one batch) at step 1225: 0.7632
# Seen so far: 19616 samples
# 0.75902325
# Training loss (for one batch) at step 1230: 0.3032
# Seen so far: 19696 samples
# 0.75964665
# Training loss (for one batch) at step 1235: 0.3357
# Seen so far: 19776 samples
# 0.76001215
# Training loss (for one batch) at step 1240: 0.4876
# Seen so far: 19856 samples
# 0.7602236
# Training loss (for one batch) at step 1245: 0.5005
# Seen so far: 19936 samples
# 0.76038325
# Training loss (for one batch) at step 1250: 0.3342
# Seen so far: 20016 samples
# 0.7609912
# Training loss (for one batch) at step 1255: 0.0530
# Seen so far: 20096 samples
# 0.7616441
# Training loss (for one batch) at step 1260: 0.2145
# Seen so far: 20176 samples
# 0.762044
# Training loss (for one batch) at step 1265: 1.1394
# Seen so far: 20256 samples
# 0.76244074
# Training loss (for one batch) at step 1270: 0.0675
# Seen so far: 20336 samples
# 0.7631786
# Training loss (for one batch) at step 1275: 0.2993
# Seen so far: 20416 samples
# 0.7635678
# Training loss (for one batch) at step 1280: 0.3164
# Seen so far: 20496 samples
# 0.7641003
# Training loss (for one batch) at step 1285: 0.7784
# Seen so far: 20576 samples
# 0.7642885
# Training loss (for one batch) at step 1290: 1.0848
# Seen so far: 20656 samples
# 0.7644268
# Training loss (for one batch) at step 1295: 0.2241
# Seen so far: 20736 samples
# 0.7647087
# Training loss (for one batch) at step 1300: 0.5793
# Seen so far: 20816 samples
# 0.7648924
# Training loss (for one batch) at step 1305: 0.0261
# Seen so far: 20896 samples
# 0.7653139
# Training loss (for one batch) at step 1310: 0.3866
# Seen so far: 20976 samples
# 0.7657799
# Training loss (for one batch) at step 1315: 0.0400
# Seen so far: 21056 samples
# 0.7662899
# Training loss (for one batch) at step 1320: 0.1265
# Seen so far: 21136 samples
# 0.7663702
# Training loss (for one batch) at step 1325: 0.7480
# Seen so far: 21216 samples
# 0.7669683
# Training loss (for one batch) at step 1330: 1.0297
# Seen so far: 21296 samples
# 0.7672333
# Training loss (for one batch) at step 1335: 0.5738
# Seen so far: 21376 samples
# 0.7675898
# Training loss (for one batch) at step 1340: 0.1082
# Seen so far: 21456 samples
# 0.7680369
# Training loss (for one batch) at step 1345: 0.4725
# Seen so far: 21536 samples
# 0.7684342
# Training loss (for one batch) at step 1350: 0.9381
# Seen so far: 21616 samples
# 0.76845855
# Training loss (for one batch) at step 1355: 0.2158
# Seen so far: 21696 samples
# 0.7688514
# Training loss (for one batch) at step 1360: 0.5911
# Seen so far: 21776 samples
# 0.76914954
# Training loss (for one batch) at step 1365: 0.2719
# Seen so far: 21856 samples
# 0.7694455
# Training loss (for one batch) at step 1370: 0.1450
# Seen so far: 21936 samples
# 0.7699672
# Training loss (for one batch) at step 1375: 0.6752
# Seen so far: 22016 samples
# 0.77039427
# Training loss (for one batch) at step 1380: 0.7336
# Seen so far: 22096 samples
# 0.77054673
# Training loss (for one batch) at step 1385: 0.1827
# Seen so far: 22176 samples
# 0.7709686
# Training loss (for one batch) at step 1390: 0.2699
# Seen so far: 22256 samples
# 0.7714324
# Training loss (for one batch) at step 1395: 0.1606
# Seen so far: 22336 samples
# 0.77166903
# Training loss (for one batch) at step 1400: 0.3356
# Seen so far: 22416 samples
# 0.7718594
# Training loss (for one batch) at step 1405: 0.3885
# Seen so far: 22496 samples
# 0.7720039
# Training loss (for one batch) at step 1410: 0.5389
# Seen so far: 22576 samples
# 0.7724132
# Training loss (for one batch) at step 1415: 0.1724
# Seen so far: 22656 samples
# 0.7727313
# Training loss (for one batch) at step 1420: 0.0689
# Seen so far: 22736 samples
# 0.7732231
# Training loss (for one batch) at step 1425: 0.1323
# Seen so far: 22816 samples
# 0.7734923
# Training loss (for one batch) at step 1430: 0.9474
# Seen so far: 22896 samples
# 0.7738033
# Training loss (for one batch) at step 1435: 0.6647
# Seen so far: 22976 samples
# 0.7741992
# Training loss (for one batch) at step 1440: 0.0383
# Seen so far: 23056 samples
# 0.7745923
# Training loss (for one batch) at step 1445: 1.0995
# Seen so far: 23136 samples
# 0.77472335
# Training loss (for one batch) at step 1450: 0.3964
# Seen so far: 23216 samples
# 0.77506894
# Training loss (for one batch) at step 1455: 0.1980
# Seen so far: 23296 samples
# 0.77536917
# Training loss (for one batch) at step 1460: 0.5151
# Seen so far: 23376 samples
# 0.77549624
# Training loss (for one batch) at step 1465: 0.4677
# Seen so far: 23456 samples
# 0.77583563
# Training loss (for one batch) at step 1470: 0.2493
# Seen so far: 23536 samples
# 0.77621514
# Training loss (for one batch) at step 1475: 0.7225
# Seen so far: 23616 samples
# 0.7762957
# Training loss (for one batch) at step 1480: 0.5050
# Seen so far: 23696 samples
# 0.7765024
# Training loss (for one batch) at step 1485: 0.3326
# Seen so far: 23776 samples
# 0.7767076
# Training loss (for one batch) at step 1490: 0.3056
# Seen so far: 23856 samples
# 0.7769534
# Training loss (for one batch) at step 1495: 0.4352
# Seen so far: 23936 samples
# 0.77715576
# Training loss (for one batch) at step 1500: 0.1875
# Seen so far: 24016 samples
# 0.7773984
# Training loss (for one batch) at step 1505: 0.6321
# Seen so far: 24096 samples
# 0.77751493
# Training loss (for one batch) at step 1510: 0.5830
# Seen so far: 24176 samples
# 0.77779615
# Training loss (for one batch) at step 1515: 0.1368
# Seen so far: 24256 samples
# 0.778158
# Training loss (for one batch) at step 1520: 0.4668
# Seen so far: 24336 samples
# 0.77847636
# Training loss (for one batch) at step 1525: 0.1354
# Seen so far: 24416 samples
# 0.77891546
# Training loss (for one batch) at step 1530: 0.4775
# Seen so far: 24496 samples
# 0.77902514
# Training loss (for one batch) at step 1535: 0.1038
# Seen so far: 24576 samples
# 0.77937824
# Training loss (for one batch) at step 1540: 0.7032
# Seen so far: 24656 samples
# 0.77936405
# Training loss (for one batch) at step 1545: 0.7214
# Seen so far: 24736 samples
# 0.77955204
# Training loss (for one batch) at step 1550: 1.0875
# Seen so far: 24816 samples
# 0.7797389
# Training loss (for one batch) at step 1555: 0.4874
# Seen so far: 24896 samples
# 0.7800048
# Training loss (for one batch) at step 1560: 0.5016
# Seen so far: 24976 samples
# 0.7801489
# Training loss (for one batch) at step 1565: 0.2925
# Seen so far: 25056 samples
# 0.7804119
# Training loss (for one batch) at step 1570: 0.2930
# Seen so far: 25136 samples
# 0.78063333
# Training loss (for one batch) at step 1575: 0.2233
# Seen so far: 25216 samples
# 0.7809327
# Training loss (for one batch) at step 1580: 0.1812
# Seen so far: 25296 samples
# 0.7812302
# Training loss (for one batch) at step 1585: 0.0155
# Seen so far: 25376 samples
# 0.7816835
# Training loss (for one batch) at step 1590: 0.8235
# Seen so far: 25456 samples
# 0.781741
# Training loss (for one batch) at step 1595: 0.7935
# Seen so far: 25536 samples
# 0.7818374
# Training loss (for one batch) at step 1600: 0.2524
# Seen so far: 25616 samples
# 0.7819332
# Training loss (for one batch) at step 1605: 0.7663
# Seen so far: 25696 samples
# 0.7822229
# Training loss (for one batch) at step 1610: 0.2423
# Seen so far: 25776 samples
# 0.78235567
# Training loss (for one batch) at step 1615: 0.1804
# Seen so far: 25856 samples
# 0.7826423
# Training loss (for one batch) at step 1620: 0.2513
# Seen so far: 25936 samples
# 0.7828115
# Training loss (for one batch) at step 1625: 0.0541
# Seen so far: 26016 samples
# 0.7831719
# Training loss (for one batch) at step 1630: 0.3529
# Seen so far: 26096 samples
# 0.78337675
# Training loss (for one batch) at step 1635: 1.0920
# Seen so far: 26176 samples
# 0.7834276
# Training loss (for one batch) at step 1640: 0.2115
# Seen so far: 26256 samples
# 0.7836685
# Training loss (for one batch) at step 1645: 0.0182
# Seen so far: 26336 samples
# 0.7839839
# Training loss (for one batch) at step 1650: 0.8143
# Seen so far: 26416 samples
# 0.7839567
# Training loss (for one batch) at step 1655: 0.4832
# Seen so far: 26496 samples
# 0.78411835
# Training loss (for one batch) at step 1660: 0.5839
# Seen so far: 26576 samples
# 0.78442955
# Training loss (for one batch) at step 1665: 0.1224
# Seen so far: 26656 samples
# 0.78466386
# Training loss (for one batch) at step 1670: 0.2928
# Seen so far: 26736 samples
# 0.7848968
# Training loss (for one batch) at step 1675: 0.1670
# Seen so far: 26816 samples
# 0.7852402
# Training loss (for one batch) at step 1680: 0.0744
# Seen so far: 26896 samples
# 0.78554434
# Training loss (for one batch) at step 1685: 0.4609
# Seen so far: 26976 samples
# 0.7858837
# Training loss (for one batch) at step 1690: 0.3427
# Seen so far: 27056 samples
# 0.78614724
# Training loss (for one batch) at step 1695: 0.2382
# Seen so far: 27136 samples
# 0.78633547
# Training loss (for one batch) at step 1700: 0.0732
# Seen so far: 27216 samples
# 0.7867063
# Training loss (for one batch) at step 1705: 0.3829
# Seen so far: 27296 samples
# 0.7869285
# Training loss (for one batch) at step 1710: 0.0630
# Seen so far: 27376 samples
# 0.7872224
# Training loss (for one batch) at step 1715: 0.2671
# Seen so far: 27456 samples
# 0.78744173
# Training loss (for one batch) at step 1720: 0.6269
# Seen so far: 27536 samples
# 0.78762347
# Training loss (for one batch) at step 1725: 0.5136
# Seen so far: 27616 samples
# 0.7876955
# Training loss (for one batch) at step 1730: 0.3166
# Seen so far: 27696 samples
# 0.78798383
# Training loss (for one batch) at step 1735: 0.3884
# Seen so far: 27776 samples
# 0.78816247
# Training loss (for one batch) at step 1740: 0.0916
# Seen so far: 27856 samples
# 0.7884836
# Training loss (for one batch) at step 1745: 0.6214
# Seen so far: 27936 samples
# 0.7886598
# Training loss (for one batch) at step 1750: 0.1028
# Seen so far: 28016 samples
# 0.78901345
# Training loss (for one batch) at step 1755: 0.0393
# Seen so far: 28096 samples
# 0.78922266
# Training loss (for one batch) at step 1760: 0.2947
# Seen so far: 28176 samples
# 0.7891823
# Training loss (for one batch) at step 1765: 0.3128
# Seen so far: 28256 samples
# 0.78938985
# Training loss (for one batch) at step 1770: 0.3965
# Seen so far: 28336 samples
# 0.78977275
# Training loss (for one batch) at step 1775: 0.6142
# Seen so far: 28416 samples
# 0.7899775
# Training loss (for one batch) at step 1780: 0.0858
# Seen so far: 28496 samples
# 0.79021615
# Training loss (for one batch) at step 1785: 0.1631
# Seen so far: 28576 samples
# 0.7905585
# Training loss (for one batch) at step 1790: 0.2924
# Seen so far: 28656 samples
# 0.79079425
# Training loss (for one batch) at step 1795: 0.2230
# Seen so far: 28736 samples
# 0.7910287
# Training loss (for one batch) at step 1800: 0.2339
# Seen so far: 28816 samples
# 0.7912965
# Training loss (for one batch) at step 1805: 0.1416
# Seen so far: 28896 samples
# 0.79149365
# Training loss (for one batch) at step 1810: 0.2430
# Seen so far: 28976 samples
# 0.79158616
# Training loss (for one batch) at step 1815: 0.1197
# Seen so far: 29056 samples
# 0.79205674
# Training loss (for one batch) at step 1820: 0.1979
# Seen so far: 29136 samples
# 0.7923531
# Training loss (for one batch) at step 1825: 0.7558
# Seen so far: 29216 samples
# 0.7926821
# Training loss (for one batch) at step 1830: 0.3629
# Seen so far: 29296 samples
# 0.7928727
# Training loss (for one batch) at step 1835: 0.4662
# Seen so far: 29376 samples
# 0.7929602
# Training loss (for one batch) at step 1840: 0.2755
# Seen so far: 29456 samples
# 0.7931491
# Training loss (for one batch) at step 1845: 0.1647
# Seen so far: 29536 samples
# 0.7932692
# Training loss (for one batch) at step 1850: 0.2088
# Seen so far: 29616 samples
# 0.79362506
# Training loss (for one batch) at step 1855: 0.2934
# Seen so far: 29696 samples
# 0.7936759
# Training loss (for one batch) at step 1860: 0.6726
# Seen so far: 29776 samples
# 0.79392797
# Training loss (for one batch) at step 1865: 0.7825
# Seen so far: 29856 samples
# 0.79404473
# Training loss (for one batch) at step 1870: 0.6467
# Seen so far: 29936 samples
# 0.79402727
# Training loss (for one batch) at step 1875: 0.0931
# Seen so far: 30016 samples
# 0.7943763
# Training loss (for one batch) at step 1880: 0.3536
# Seen so far: 30096 samples
# 0.79462385
# Training loss (for one batch) at step 1885: 0.5184
# Seen so far: 30176 samples
# 0.7948701
# Training loss (for one batch) at step 1890: 0.2891
# Seen so far: 30256 samples
# 0.795082
# Training loss (for one batch) at step 1895: 0.1396
# Seen so far: 30336 samples
# 0.7953916
# Training loss (for one batch) at step 1900: 0.8214
# Seen so far: 30416 samples
# 0.79546946
# Training loss (for one batch) at step 1905: 0.4241
# Seen so far: 30496 samples
# 0.7956125
# Training loss (for one batch) at step 1910: 0.1558
# Seen so far: 30576 samples
# 0.7958857
# Training loss (for one batch) at step 1915: 0.0418
# Seen so far: 30656 samples
# 0.7962226
# Training loss (for one batch) at step 1920: 0.2390
# Seen so far: 30736 samples
# 0.79652524
# Training loss (for one batch) at step 1925: 0.1516
# Seen so far: 30816 samples
# 0.79663163
# Training loss (for one batch) at step 1930: 0.0658
# Seen so far: 30896 samples
# 0.79673743
# Training loss (for one batch) at step 1935: 0.5957
# Seen so far: 30976 samples
# 0.79693955
# Training loss (for one batch) at step 1940: 0.2155
# Seen so far: 31056 samples
# 0.79720503
# Training loss (for one batch) at step 1945: 0.3360
# Seen so far: 31136 samples
# 0.7974371
# Training loss (for one batch) at step 1950: 0.6575
# Seen so far: 31216 samples
# 0.7976038
# Training loss (for one batch) at step 1955: 0.2735
# Seen so far: 31296 samples
# 0.79786557
# Training loss (for one batch) at step 1960: 0.8661
# Seen so far: 31376 samples
# 0.7980622
# Training loss (for one batch) at step 1965: 0.0995
# Seen so far: 31456 samples
# 0.798385
# Training loss (for one batch) at step 1970: 0.0592
# Seen so far: 31536 samples
# 0.7985477
# Training loss (for one batch) at step 1975: 0.1930
# Seen so far: 31616 samples
# 0.79867786
# Training loss (for one batch) at step 1980: 0.5774
# Seen so far: 31696 samples
# 0.7989336
# Training loss (for one batch) at step 1985: 0.1810
# Seen so far: 31776 samples
# 0.7991881
# Training loss (for one batch) at step 1990: 0.3384
# Seen so far: 31856 samples
# 0.79934704
# Training loss (for one batch) at step 1995: 0.2832
# Seen so far: 31936 samples
# 0.79950523
# Training loss (for one batch) at step 2000: 0.0589
# Seen so far: 32016 samples
# 0.7997251
# Training loss (for one batch) at step 2005: 0.0629
# Seen so far: 32096 samples
# 0.7999751
# Training loss (for one batch) at step 2010: 0.4799
# Seen so far: 32176 samples
# 0.80022377
# Training loss (for one batch) at step 2015: 0.5970
# Seen so far: 32256 samples
# 0.80044025
# Training loss (for one batch) at step 2020: 1.0837
# Seen so far: 32336 samples
# 0.8005319
# Training loss (for one batch) at step 2025: 0.5017
# Seen so far: 32416 samples
# 0.8009008
# Training loss (for one batch) at step 2030: 0.2509
# Seen so far: 32496 samples
# 0.8012063
# Training loss (for one batch) at step 2035: 0.3902
# Seen so far: 32576 samples
# 0.80147964
# Training loss (for one batch) at step 2040: 0.2248
# Seen so far: 32656 samples
# 0.801721
# Training loss (for one batch) at step 2045: 0.0757
# Seen so far: 32736 samples
# 0.8018084
# Training loss (for one batch) at step 2050: 0.2166
# Seen so far: 32816 samples
# 0.8021392
# Training loss (for one batch) at step 2055: 0.0547
# Seen so far: 32896 samples
# 0.80237716
# Training loss (for one batch) at step 2060: 0.1576
# Seen so far: 32976 samples
# 0.8024624
# Training loss (for one batch) at step 2065: 0.4657
# Seen so far: 33056 samples
# 0.8026077
# Training loss (for one batch) at step 2070: 0.8520
# Seen so far: 33136 samples
# 0.80281264
# Training loss (for one batch) at step 2075: 0.2425
# Seen so far: 33216 samples
# 0.8029564
# Training loss (for one batch) at step 2080: 0.2955
# Seen so far: 33296 samples
# 0.8031295
# Training loss (for one batch) at step 2085: 0.4439
# Seen so far: 33376 samples
# 0.80324185
# Training loss (for one batch) at step 2090: 0.5503
# Seen so far: 33456 samples
# 0.8035031
# Training loss (for one batch) at step 2095: 0.6447
# Seen so far: 33536 samples
# 0.8033755
# Training loss (for one batch) at step 2100: 0.2485
# Seen so far: 33616 samples
# 0.8033972
# Training loss (for one batch) at step 2105: 0.3871
# Seen so far: 33696 samples
# 0.8036859
# Training loss (for one batch) at step 2110: 0.4015
# Seen so far: 33776 samples
# 0.803914
# Training loss (for one batch) at step 2115: 0.1600
# Seen so far: 33856 samples
# 0.8040525
# Training loss (for one batch) at step 2120: 0.0977
# Seen so far: 33936 samples
# 0.80433756
# Training loss (for one batch) at step 2125: 0.2243
# Seen so far: 34016 samples
# 0.80450374
# Training loss (for one batch) at step 2130: 0.2035
# Seen so far: 34096 samples
# 0.80466914
# Training loss (for one batch) at step 2135: 0.4258
# Seen so far: 34176 samples
# 0.80474603
# Training loss (for one batch) at step 2140: 0.5723
# Seen so far: 34256 samples
# 0.80493927
# Training loss (for one batch) at step 2145: 0.9703
# Seen so far: 34336 samples
# 0.8050443
# Training loss (for one batch) at step 2150: 0.0678
# Seen so far: 34416 samples
# 0.8052069
# Training loss (for one batch) at step 2155: 0.4186
# Seen so far: 34496 samples
# 0.80539775
# Training loss (for one batch) at step 2160: 0.7468
# Seen so far: 34576 samples
# 0.805472
# Training loss (for one batch) at step 2165: 0.3876
# Seen so far: 34656 samples
# 0.8056614
# Training loss (for one batch) at step 2170: 0.4974
# Seen so far: 34736 samples
# 0.8057635
# Training loss (for one batch) at step 2175: 0.4504
# Seen so far: 34816 samples
# 0.8060374
# Training loss (for one batch) at step 2180: 0.4469
# Seen so far: 34896 samples
# 0.80605227
# Training loss (for one batch) at step 2185: 0.8998
# Seen so far: 34976 samples
# 0.80626714
# Training loss (for one batch) at step 2190: 0.2210
# Seen so far: 35056 samples
# 0.8063384
# Training loss (for one batch) at step 2195: 0.0173
# Seen so far: 35136 samples
# 0.8065801
# Training loss (for one batch) at step 2200: 0.4140
# Seen so far: 35216 samples
# 0.8067924
# Training loss (for one batch) at step 2205: 0.6362
# Seen so far: 35296 samples
# 0.8068053
# Training loss (for one batch) at step 2210: 0.7693
# Seen so far: 35376 samples
# 0.8070161
# Training loss (for one batch) at step 2215: 0.4528
# Seen so far: 35456 samples
# 0.80708486
# Training loss (for one batch) at step 2220: 0.6429
# Seen so far: 35536 samples
# 0.8072096
# Training loss (for one batch) at step 2225: 0.1115
# Seen so far: 35616 samples
# 0.80736184
# Training loss (for one batch) at step 2230: 0.5330
# Seen so far: 35696 samples
# 0.8075695
# Training loss (for one batch) at step 2235: 0.6964
# Seen so far: 35776 samples
# 0.8075246
# Training loss (for one batch) at step 2240: 0.4959
# Seen so far: 35856 samples
# 0.807703
# Training loss (for one batch) at step 2245: 0.0802
# Seen so far: 35936 samples
# 0.8077972
# Training loss (for one batch) at step 2250: 0.8204
# Seen so far: 36016 samples
# 0.8076966
# Training loss (for one batch) at step 2255: 0.1883
# Seen so far: 36096 samples
# 0.80790114
# Training loss (for one batch) at step 2260: 1.0196
# Seen so far: 36176 samples
# 0.80782837
# Training loss (for one batch) at step 2265: 0.6078
# Seen so far: 36256 samples
# 0.8078663
# Training loss (for one batch) at step 2270: 0.1512
# Seen so far: 36336 samples
# 0.8080141
# Training loss (for one batch) at step 2275: 0.2939
# Seen so far: 36416 samples
# 0.80821615
# Training loss (for one batch) at step 2280: 0.3380
# Seen so far: 36496 samples
# 0.80844474
# Training loss (for one batch) at step 2285: 0.0464
# Seen so far: 36576 samples
# 0.80859035
# Training loss (for one batch) at step 2290: 1.2561
# Seen so far: 36656 samples
# 0.808708
# Training loss (for one batch) at step 2295: 0.1225
# Seen so far: 36736 samples
# 0.80882514
# Training loss (for one batch) at step 2300: 0.1283
# Seen so far: 36816 samples
# 0.80902326
# Training loss (for one batch) at step 2305: 0.1453
# Seen so far: 36896 samples
# 0.8091663
# Training loss (for one batch) at step 2310: 0.0534
# Seen so far: 36976 samples
# 0.8093628
# Training loss (for one batch) at step 2315: 0.6680
# Seen so far: 37056 samples
# 0.8095045
# Training loss (for one batch) at step 2320: 0.2105
# Seen so far: 37136 samples
# 0.80959177
# Training loss (for one batch) at step 2325: 0.6084
# Seen so far: 37216 samples
# 0.809598
# Training loss (for one batch) at step 2330: 0.0980
# Seen so far: 37296 samples
# 0.80981874
# Training loss (for one batch) at step 2335: 0.1921
# Seen so far: 37376 samples
# 0.80998504
# Training loss (for one batch) at step 2340: 0.5861
# Seen so far: 37456 samples
# 0.8099904
# Training loss (for one batch) at step 2345: 0.8038
# Seen so far: 37536 samples
# 0.81002235
# Training loss (for one batch) at step 2350: 0.3967
# Seen so far: 37616 samples
# 0.8101074
# Training loss (for one batch) at step 2355: 0.1573
# Seen so far: 37696 samples
# 0.8103247
# Training loss (for one batch) at step 2360: 0.2326
# Seen so far: 37776 samples
# 0.81048816
# Training loss (for one batch) at step 2365: 0.9823
# Seen so far: 37856 samples
# 0.8105716
# Training loss (for one batch) at step 2370: 0.1887
# Seen so far: 37936 samples
# 0.81060207
# Training loss (for one batch) at step 2375: 0.1958
# Seen so far: 38016 samples
# 0.81071126
# Training loss (for one batch) at step 2380: 0.3269
# Seen so far: 38096 samples
# 0.8108988
# Training loss (for one batch) at step 2385: 0.5683
# Seen so far: 38176 samples
# 0.8109545
# Training loss (for one batch) at step 2390: 0.1352
# Seen so far: 38256 samples
# 0.8112453
# Training loss (for one batch) at step 2395: 0.5152
# Seen so far: 38336 samples
# 0.8114305
# Training loss (for one batch) at step 2400: 0.4403
# Seen so far: 38416 samples
# 0.81158894
# Training loss (for one batch) at step 2405: 0.1166
# Seen so far: 38496 samples
# 0.81166875
# Training loss (for one batch) at step 2410: 0.3975
# Seen so far: 38576 samples
# 0.811826
# Training loss (for one batch) at step 2415: 0.2502
# Seen so far: 38656 samples
# 0.8118533
# Training loss (for one batch) at step 2420: 0.8058
# Seen so far: 38736 samples
# 0.8118804
# Training loss (for one batch) at step 2425: 0.0791
# Seen so far: 38816 samples
# 0.8121136
# Training loss (for one batch) at step 2430: 0.5770
# Seen so far: 38896 samples
# 0.8122686
# Training loss (for one batch) at step 2435: 0.3901
# Seen so far: 38976 samples
# 0.81239736
# Training loss (for one batch) at step 2440: 0.4963
# Seen so far: 39056 samples
# 0.81252563
# Training loss (for one batch) at step 2445: 0.1512
# Seen so far: 39136 samples
# 0.8126022
# Training loss (for one batch) at step 2450: 0.0999
# Seen so far: 39216 samples
# 0.812857
# Training loss (for one batch) at step 2455: 0.6507
# Seen so far: 39296 samples
# 0.8131362
# Training loss (for one batch) at step 2460: 0.0461
# Seen so far: 39376 samples
# 0.81328726
# Training loss (for one batch) at step 2465: 0.6412
# Seen so far: 39456 samples
# 0.81338704
# Training loss (for one batch) at step 2470: 0.7311
# Seen so far: 39536 samples
# 0.813537
# Training loss (for one batch) at step 2475: 0.3397
# Seen so far: 39616 samples
# 0.81373686
# Training loss (for one batch) at step 2480: 0.2738
# Seen so far: 39696 samples
# 0.8139863
# Training loss (for one batch) at step 2485: 0.7884
# Seen so far: 39776 samples
# 0.8139833
# Training loss (for one batch) at step 2490: 0.0816
# Seen so far: 39856 samples
# 0.8142061
# Training loss (for one batch) at step 2495: 0.1626
# Seen so far: 39936 samples
# 0.8142778
# Training loss (for one batch) at step 2500: 0.3661
# Seen so far: 40016 samples
# 0.8144492
# Training loss (for one batch) at step 2505: 0.2211
# Seen so far: 40096 samples
# 0.8145202
# Training loss (for one batch) at step 2510: 0.1024
# Seen so far: 40176 samples
# 0.81471527
# Training loss (for one batch) at step 2515: 0.1178
# Seen so far: 40256 samples
# 0.8147605
# Training loss (for one batch) at step 2520: 0.3813
# Seen so far: 40336 samples
# 0.8149544
# Training loss (for one batch) at step 2525: 0.2481
# Seen so far: 40416 samples
# 0.81514746
# Training loss (for one batch) at step 2530: 0.2591
# Seen so far: 40496 samples
# 0.8152904
# Training loss (for one batch) at step 2535: 0.2479
# Seen so far: 40576 samples
# 0.8155067
# Training loss (for one batch) at step 2540: 0.6125
# Seen so far: 40656 samples
# 0.8155992
# Training loss (for one batch) at step 2545: 0.0060
# Seen so far: 40736 samples
# 0.8157404
# Training loss (for one batch) at step 2550: 0.6425
# Seen so far: 40816 samples
# 0.815783
# Training loss (for one batch) at step 2555: 0.2327
# Seen so far: 40896 samples
# 0.81589884
# Training loss (for one batch) at step 2560: 0.0407
# Seen so far: 40976 samples
# 0.8160875
# Training loss (for one batch) at step 2565: 0.0968
# Seen so far: 41056 samples
# 0.8161779
# Training loss (for one batch) at step 2570: 0.4306
# Seen so far: 41136 samples
# 0.81614643
# Training loss (for one batch) at step 2575: 0.1282
# Seen so far: 41216 samples
# 0.8162607
# Training loss (for one batch) at step 2580: 0.0581
# Seen so far: 41296 samples
# 0.81649554
# Training loss (for one batch) at step 2585: 0.3526
# Seen so far: 41376 samples
# 0.816657
# Training loss (for one batch) at step 2590: 0.7427
# Seen so far: 41456 samples
# 0.81650424
# Training loss (for one batch) at step 2595: 1.0344
# Seen so far: 41536 samples
# 0.81656873
# Training loss (for one batch) at step 2600: 0.9757
# Seen so far: 41616 samples
# 0.81663305
# Training loss (for one batch) at step 2605: 0.3222
# Seen so far: 41696 samples
# 0.816745
# Training loss (for one batch) at step 2610: 0.0766
# Seen so far: 41776 samples
# 0.8169523
# Training loss (for one batch) at step 2615: 0.0527
# Seen so far: 41856 samples
# 0.8171588
# Training loss (for one batch) at step 2620: 0.3985
# Seen so far: 41936 samples
# 0.817293
# Training loss (for one batch) at step 2625: 0.1283
# Seen so far: 42016 samples
# 0.8174743
# Training loss (for one batch) at step 2630: 0.8475
# Seen so far: 42096 samples
# 0.8175836
# Training loss (for one batch) at step 2635: 0.5805
# Seen so far: 42176 samples
# 0.8176214
# Training loss (for one batch) at step 2640: 0.4834
# Seen so far: 42256 samples
# 0.81777734
# Training loss (for one batch) at step 2645: 0.0847
# Seen so far: 42336 samples
# 0.8180272
# Training loss (for one batch) at step 2650: 0.2096
# Seen so far: 42416 samples
# 0.81815827
# Training loss (for one batch) at step 2655: 0.6716
# Seen so far: 42496 samples
# 0.81812406
# Training loss (for one batch) at step 2660: 0.8618
# Seen so far: 42576 samples
# 0.8181605
# Training loss (for one batch) at step 2665: 0.9227
# Seen so far: 42656 samples
# 0.8182436
# Training loss (for one batch) at step 2670: 0.4208
# Seen so far: 42736 samples
# 0.8182797
# Training loss (for one batch) at step 2675: 0.4906
# Seen so far: 42816 samples
# 0.8184557
# Training loss (for one batch) at step 2680: 0.5865
# Seen so far: 42896 samples
# 0.8185145
# Training loss (for one batch) at step 2685: 0.5966
# Seen so far: 42976 samples
# 0.8187128
# Training loss (for one batch) at step 2690: 0.6589
# Seen so far: 43056 samples
# 0.81891024
# Training loss (for one batch) at step 2695: 0.3194
# Seen so far: 43136 samples
# 0.81901425
# Training loss (for one batch) at step 2700: 1.7969
# Seen so far: 43216 samples
# 0.8190485
# Training loss (for one batch) at step 2705: 0.1588
# Seen so far: 43296 samples
# 0.819175
# Training loss (for one batch) at step 2710: 0.1731
# Seen so far: 43376 samples
# 0.81937015
# Training loss (for one batch) at step 2715: 0.3026
# Seen so far: 43456 samples
# 0.81963366
# Training loss (for one batch) at step 2720: 0.4308
# Seen so far: 43536 samples
# 0.81968945
# Training loss (for one batch) at step 2725: 0.3122
# Seen so far: 43616 samples
# 0.8197909
# Training loss (for one batch) at step 2730: 0.4201
# Seen so far: 43696 samples
# 0.819686
# ...
# Training loss (for one batch) at step 8120: 0.2091
# Seen so far: 129936 samples
# 0.88596696
# Training loss (for one batch) at step 8125: 0.0047
# Seen so far: 130016 samples
# 0.88602173
# Training loss (for one batch) at step 8130: 0.1234
# Seen so far: 130096 samples
# 0.8860611
# Training loss (for one batch) at step 8135: 0.0181
# Seen so far: 130176 samples
# 0.8861311
# Training loss (for one batch) at step 8140: 0.0154
# Seen so far: 130256 samples
# 0.88616264
# Training loss (for one batch) at step 8145: 0.2352
# Seen so far: 130336 samples
# 0.8861865
# Training loss (for one batch) at step 8150: 0.2348
# Seen so far: 130416 samples
# 0.88619494
# Training loss (for one batch) at step 8155: 0.7023
# Seen so far: 130496 samples
# 0.8862034
# Training loss (for one batch) at step 8160: 0.0677
# Seen so far: 130576 samples
# 0.88625014
# Training loss (for one batch) at step 8165: 0.0738
# Seen so far: 130656 samples
# 0.88629687
# Training loss (for one batch) at step 8170: 0.0033
# Seen so far: 130736 samples
# 0.88632816
# Training loss (for one batch) at step 8175: 0.0014
# Seen so far: 130816 samples
# 0.8863365
# Training loss (for one batch) at step 8180: 0.4917
# Seen so far: 130896 samples
# 0.88636017
# Training loss (for one batch) at step 8185: 0.2937
# Seen so far: 130976 samples
# 0.88640666
# Training loss (for one batch) at step 8190: 0.0080
# Seen so far: 131056 samples
# 0.88646835
# Training loss (for one batch) at step 8195: 0.7180
# Seen so far: 131136 samples
# 0.88648427
# Training loss (for one batch) at step 8200: 0.0221
# Seen so far: 131216 samples
# 0.88650775
# Training loss (for one batch) at step 8205: 0.2243
# Seen so far: 131296 samples
# 0.88650835
# Training loss (for one batch) at step 8210: 0.0990
# Seen so far: 131376 samples
# 0.886547
# Training loss (for one batch) at step 8215: 0.6336
# Seen so far: 131456 samples
# 0.88658565
# Training loss (for one batch) at step 8220: 0.0565
# Seen so far: 131536 samples
# 0.886609
# Training loss (for one batch) at step 8225: 0.8201
# Seen so far: 131616 samples
# 0.8866399
# Training loss (for one batch) at step 8230: 0.5011
# Seen so far: 131696 samples
# 0.88664806
# Training loss (for one batch) at step 8235: 0.2022
# Seen so far: 131776 samples
# 0.88667893
# Training loss (for one batch) at step 8240: 0.4484
# Seen so far: 131856 samples
# 0.88669455
# Training loss (for one batch) at step 8245: 0.5804
# Seen so far: 131936 samples
# 0.88672537
# Training loss (for one batch) at step 8250: 0.0144
# Seen so far: 132016 samples
# 0.8867713
# Training loss (for one batch) at step 8255: 0.0112
# Seen so far: 132096 samples
# 0.8868247
# Training loss (for one batch) at step 8260: 0.2175
# Seen so far: 132176 samples
# 0.8868554
# Training loss (for one batch) at step 8265: 0.1746
# Seen so far: 132256 samples
# 0.88689363
# Training loss (for one batch) at step 8270: 0.0837
# Seen so far: 132336 samples
# 0.88691664
# Training loss (for one batch) at step 8275: 0.0967
# Seen so far: 132416 samples
# 0.8869547
# Training loss (for one batch) at step 8280: 0.2602
# Seen so far: 132496 samples
# 0.88698524
# Training loss (for one batch) at step 8285: 0.0033
# Seen so far: 132576 samples
# 0.8870082
# Training loss (for one batch) at step 8290: 0.0373
# Seen so far: 132656 samples
# 0.8870462
# Training loss (for one batch) at step 8295: 0.1898
# Seen so far: 132736 samples
# 0.8870917
# Training loss (for one batch) at step 8300: 0.2765
# Seen so far: 132816 samples
# 0.88712204
# Training loss (for one batch) at step 8305: 0.2528
# Seen so far: 132896 samples
# 0.88714486
# Training loss (for one batch) at step 8310: 0.0110
# Seen so far: 132976 samples
# 0.8871977
# Training loss (for one batch) at step 8315: 0.7199
# Seen so far: 133056 samples
# 0.88722795
# Training loss (for one batch) at step 8320: 0.0083
# Seen so far: 133136 samples
# 0.8872431
# Training loss (for one batch) at step 8325: 0.0185
# Seen so far: 133216 samples
# 0.88728833
# Training loss (for one batch) at step 8330: 0.0571
# Seen so far: 133296 samples
# 0.8873035
# Training loss (for one batch) at step 8335: 0.0035
# Seen so far: 133376 samples
# 0.88734853
# Training loss (for one batch) at step 8340: 0.0621
# Seen so far: 133456 samples
# 0.8873711
# Training loss (for one batch) at step 8345: 0.0141
# Seen so far: 133536 samples
# 0.88739365
# Training loss (for one batch) at step 8350: 0.0676
# Seen so far: 133616 samples
# 0.8874162
# Training loss (for one batch) at step 8355: 0.0714
# Seen so far: 133696 samples
# 0.88748354
# Training loss (for one batch) at step 8360: 0.1495
# Seen so far: 133776 samples
# 0.8875209
# Training loss (for one batch) at step 8365: 0.0860
# Seen so far: 133856 samples
# 0.88756573
# Training loss (for one batch) at step 8370: 0.1708
# Seen so far: 133936 samples
# 0.8875881
# Training loss (for one batch) at step 8375: 0.0059
# Seen so far: 134016 samples
# 0.88759553
# Training loss (for one batch) at step 8380: 0.0507
# Seen so far: 134096 samples
# 0.8876476
# Training loss (for one batch) at step 8385: 0.2335
# Seen so far: 134176 samples
# 0.8876774
# Training loss (for one batch) at step 8390: 0.0223
# Seen so far: 134256 samples
# 0.88770705
# Training loss (for one batch) at step 8395: 0.0348
# Seen so far: 134336 samples
# 0.8877293
# Training loss (for one batch) at step 8400: 0.0224
# Seen so far: 134416 samples
# 0.88777375
# Training loss (for one batch) at step 8405: 0.4023
# Seen so far: 134496 samples
# 0.8877959
# Training loss (for one batch) at step 8410: 0.0116
# Seen so far: 134576 samples
# 0.8878552
# Training loss (for one batch) at step 8415: 0.8380
# Seen so far: 134656 samples
# 0.8878995
# Training loss (for one batch) at step 8420: 0.1648
# Seen so far: 134736 samples
# 0.88792896
# Training loss (for one batch) at step 8425: 0.0127
# Seen so far: 134816 samples
# 0.88797325
# Training loss (for one batch) at step 8430: 0.0772
# Seen so far: 134896 samples
# 0.88798034
# Training loss (for one batch) at step 8435: 0.0225
# Seen so far: 134976 samples
# 0.8880245
# Training loss (for one batch) at step 8440: 0.1058
# Seen so far: 135056 samples
# 0.8880612
# Training loss (for one batch) at step 8445: 0.1890
# Seen so far: 135136 samples
# 0.8880609
# Training loss (for one batch) at step 8450: 0.0700
# Seen so far: 135216 samples
# 0.8880976
# Training loss (for one batch) at step 8455: 0.4203
# Seen so far: 135296 samples
# 0.888112
# Training loss (for one batch) at step 8460: 0.1352
# Seen so far: 135376 samples
# 0.88813376
# Training loss (for one batch) at step 8465: 0.0295
# Seen so far: 135456 samples
# 0.8881925
# Training loss (for one batch) at step 8470: 0.2878
# Seen so far: 135536 samples
# 0.88820684
# Training loss (for one batch) at step 8475: 0.3950
# Seen so far: 135616 samples
# 0.8881769
# Training loss (for one batch) at step 8480: 0.0307
# Seen so far: 135696 samples
# 0.88823545
# Training loss (for one batch) at step 8485: 0.0341
# Seen so far: 135776 samples
# 0.88824975
# Training loss (for one batch) at step 8490: 0.1629
# Seen so far: 135856 samples
# 0.8882935
# Training loss (for one batch) at step 8495: 0.0940
# Seen so far: 135936 samples
# 0.88833714
# Training loss (for one batch) at step 8500: 0.1651
# Seen so far: 136016 samples
# 0.88837343
# Training loss (for one batch) at step 8505: 0.2261
# Seen so far: 136096 samples
# 0.88839495
# Training loss (for one batch) at step 8510: 0.0879
# Seen so far: 136176 samples
# 0.88843113
# Training loss (for one batch) at step 8515: 0.0624
# Seen so far: 136256 samples
# 0.88846
# Training loss (for one batch) at step 8520: 0.1655
# Seen so far: 136336 samples
# 0.88850343
# Training loss (for one batch) at step 8525: 0.0057
# Seen so far: 136416 samples
# 0.8885615
# Training loss (for one batch) at step 8530: 0.0640
# Seen so far: 136496 samples
# 0.8886121
# Training loss (for one batch) at step 8535: 0.4960
# Seen so far: 136576 samples
# 0.8886481
# Training loss (for one batch) at step 8540: 0.0068
# Seen so far: 136656 samples
# 0.88869864
# Training loss (for one batch) at step 8545: 0.0115
# Seen so far: 136736 samples
# 0.8887345
# Training loss (for one batch) at step 8550: 0.0107
# Seen so far: 136816 samples
# 0.8887776
# Training loss (for one batch) at step 8555: 0.1265
# Seen so far: 136896 samples
# 0.8887988
# Training loss (for one batch) at step 8560: 0.0871
# Seen so far: 136976 samples
# 0.8888565
# Training loss (for one batch) at step 8565: 0.0106
# Seen so far: 137056 samples
# 0.8889213
# Training loss (for one batch) at step 8570: 0.0295
# Seen so far: 137136 samples
# 0.88894963
# Training loss (for one batch) at step 8575: 0.1246
# Seen so far: 137216 samples
# 0.88899255
# Training loss (for one batch) at step 8580: 0.3098
# Seen so far: 137296 samples
# 0.88900626
# Training loss (for one batch) at step 8585: 0.0123
# Seen so far: 137376 samples
# 0.8890636
# Training loss (for one batch) at step 8590: 0.2346
# Seen so far: 137456 samples
# 0.88907
# Training loss (for one batch) at step 8595: 0.0111
# Seen so far: 137536 samples
# 0.8890981
# Training loss (for one batch) at step 8600: 0.1804
# Seen so far: 137616 samples
# 0.88912624
# Training loss (for one batch) at step 8605: 0.0526
# Seen so far: 137696 samples
# 0.88916165
# Training loss (for one batch) at step 8610: 0.0056
# Seen so far: 137776 samples
# 0.8891897
# Training loss (for one batch) at step 8615: 0.0922
# Seen so far: 137856 samples
# 0.889225
# Training loss (for one batch) at step 8620: 0.2624
# Seen so far: 137936 samples
# 0.88923126
# Training loss (for one batch) at step 8625: 0.0866
# Seen so far: 138016 samples
# 0.88924474
# Training loss (for one batch) at step 8630: 0.1044
# Seen so far: 138096 samples
# 0.8892727
# Training loss (for one batch) at step 8635: 0.0138
# Seen so far: 138176 samples
# 0.88932234
# Training loss (for one batch) at step 8640: 0.0430
# Seen so far: 138256 samples
# 0.88937914
# Training loss (for one batch) at step 8645: 0.1356
# Seen so far: 138336 samples
# 0.8893925
# Training loss (for one batch) at step 8650: 0.2093
# Seen so far: 138416 samples
# 0.88944197
# Training loss (for one batch) at step 8655: 0.0384
# Seen so far: 138496 samples
# 0.88947695
# Training loss (for one batch) at step 8660: 0.0632
# Seen so far: 138576 samples
# 0.8895335
# Training loss (for one batch) at step 8665: 0.5825
# Seen so far: 138656 samples
# 0.88956845
# Training loss (for one batch) at step 8670: 0.0037
# Seen so far: 138736 samples
# 0.8896177
# Training loss (for one batch) at step 8675: 0.0875
# Seen so far: 138816 samples
# 0.8896453
# Training loss (for one batch) at step 8680: 0.0018
# Seen so far: 138896 samples
# 0.88968724
# Training loss (for one batch) at step 8685: 0.2967
# Seen so far: 138976 samples
# 0.889722
# Training loss (for one batch) at step 8690: 0.2766
# Seen so far: 139056 samples
# 0.88976383
# Training loss (for one batch) at step 8695: 0.1837
# Seen so far: 139136 samples
# 0.8897769
# Training loss (for one batch) at step 8700: 0.1073
# Seen so far: 139216 samples
# 0.8898043
# Training loss (for one batch) at step 8705: 0.0827
# Seen so far: 139296 samples
# 0.88986045
# Training loss (for one batch) at step 8710: 0.6103
# Seen so far: 139376 samples
# 0.8898878
# Training loss (for one batch) at step 8715: 0.0665
# Seen so far: 139456 samples
# 0.88992226
# Training loss (for one batch) at step 8720: 0.2414
# Seen so far: 139536 samples
# 0.88997823
# Training loss (for one batch) at step 8725: 0.1737
# Seen so far: 139616 samples
# 0.8900269
# Training loss (for one batch) at step 8730: 0.0287
# Seen so far: 139696 samples
# 0.89007556
# Training loss (for one batch) at step 8735: 0.0236
# Seen so far: 139776 samples
# 0.8900956
# Training loss (for one batch) at step 8740: 0.0041
# Seen so far: 139856 samples
# 0.890137
# Training loss (for one batch) at step 8745: 0.0050
# Seen so far: 139936 samples
# 0.8901784
# Training loss (for one batch) at step 8750: 0.0334
# Seen so far: 140016 samples
# 0.89021254
# Training loss (for one batch) at step 8755: 0.1070
# Seen so far: 140096 samples
# 0.8902324
# Training loss (for one batch) at step 8760: 0.0853
# Seen so far: 140176 samples
# 0.89020234
# Training loss (for one batch) at step 8765: 0.0349
# Seen so far: 140256 samples
# 0.8902293
# Training loss (for one batch) at step 8770: 0.0217
# Seen so far: 140336 samples
# 0.8902776
# Training loss (for one batch) at step 8775: 0.0791
# Seen so far: 140416 samples
# 0.8903259
# Training loss (for one batch) at step 8780: 0.0096
# Seen so far: 140496 samples
# 0.8903812
# Training loss (for one batch) at step 8785: 0.2074
# Seen so far: 140576 samples
# 0.8904294
# Training loss (for one batch) at step 8790: 0.1416
# Seen so far: 140656 samples
# 0.8904704
# Training loss (for one batch) at step 8795: 0.0926
# Seen so far: 140736 samples
# 0.8905326
# Training loss (for one batch) at step 8800: 0.1487
# Seen so far: 140816 samples
# 0.8905593
# Training loss (for one batch) at step 8805: 0.0196
# Seen so far: 140896 samples
# 0.89059305
# Training loss (for one batch) at step 8810: 0.0657
# Seen so far: 140976 samples
# 0.890641
# Training loss (for one batch) at step 8815: 0.0102
# Seen so far: 141056 samples
# 0.89070296
# Training loss (for one batch) at step 8820: 0.2824
# Seen so far: 141136 samples
# 0.8907366
# Training loss (for one batch) at step 8825: 0.1713
# Seen so far: 141216 samples
# 0.8907843
# Training loss (for one batch) at step 8830: 0.1933
# Seen so far: 141296 samples
# 0.8908108
# Training loss (for one batch) at step 8835: 0.0710
# Seen so far: 141376 samples
# 0.8908584
# Training loss (for one batch) at step 8840: 0.0521
# Seen so far: 141456 samples
# 0.8908848
# Training loss (for one batch) at step 8845: 1.0798
# Seen so far: 141536 samples
# 0.89091116
# Training loss (for one batch) at step 8850: 0.4096
# Seen so far: 141616 samples
# 0.8909516
# Training loss (for one batch) at step 8855: 0.1245
# Seen so far: 141696 samples
# 0.890992
# Training loss (for one batch) at step 8860: 0.0019
# Seen so far: 141776 samples
# 0.8910394
# Training loss (for one batch) at step 8865: 0.5409
# Seen so far: 141856 samples
# 0.89107966
# Training loss (for one batch) at step 8870: 0.0150
# Seen so far: 141936 samples
# 0.89111996
# Training loss (for one batch) at step 8875: 0.3237
# Seen so far: 142016 samples
# 0.8911531
# Training loss (for one batch) at step 8880: 0.0142
# Seen so far: 142096 samples
# 0.89116514
# Training loss (for one batch) at step 8885: 0.1616
# Seen so far: 142176 samples
# 0.89120525
# Training loss (for one batch) at step 8890: 0.0375
# Seen so far: 142256 samples
# 0.8912524
# Training loss (for one batch) at step 8895: 0.1528
# Seen so far: 142336 samples
# 0.8912784
# Training loss (for one batch) at step 8900: 0.0098
# Seen so far: 142416 samples
# 0.8913184
# Training loss (for one batch) at step 8905: 0.2186
# Seen so far: 142496 samples
# 0.8913584
# Training loss (for one batch) at step 8910: 0.5375
# Seen so far: 142576 samples
# 0.89137024
# Training loss (for one batch) at step 8915: 0.2559
# Seen so far: 142656 samples
# 0.8913961
# Training loss (for one batch) at step 8920: 0.2916
# Seen so far: 142736 samples
# 0.89144295
# Training loss (for one batch) at step 8925: 0.6773
# Seen so far: 142816 samples
# 0.89144075
# Training loss (for one batch) at step 8930: 0.1604
# Seen so far: 142896 samples
# 0.8914595
# Training loss (for one batch) at step 8935: 0.0006
# Seen so far: 142976 samples
# 0.8914783
# Training loss (for one batch) at step 8940: 0.4407
# Seen so far: 143056 samples
# 0.89149004
# Training loss (for one batch) at step 8945: 0.1049
# Seen so far: 143136 samples
# 0.89151573
# Training loss (for one batch) at step 8950: 0.0353
# Seen so far: 143216 samples
# 0.89154845
# Training loss (for one batch) at step 8955: 0.1188
# Seen so far: 143296 samples
# 0.89158106
# Training loss (for one batch) at step 8960: 0.1870
# Seen so far: 143376 samples
# 0.8915788
# Training loss (for one batch) at step 8965: 0.1815
# Seen so far: 143456 samples
# 0.8915905
# Training loss (for one batch) at step 8970: 0.8636
# Seen so far: 143536 samples
# 0.8916091
# Training loss (for one batch) at step 8975: 0.2604
# Seen so far: 143616 samples
# 0.89163464
# Training loss (for one batch) at step 8980: 0.0677
# Seen so far: 143696 samples
# 0.8916741
# Training loss (for one batch) at step 8985: 0.1389
# Seen so far: 143776 samples
# 0.8916996
# Training loss (for one batch) at step 8990: 0.0944
# Seen so far: 143856 samples
# 0.89173204
# Training loss (for one batch) at step 8995: 0.6393
# Seen so far: 143936 samples
# 0.89172965
# Training loss (for one batch) at step 9000: 0.2225
# Seen so far: 144016 samples
# 0.8917273
# Training loss (for one batch) at step 9005: 0.3136
# Seen so far: 144096 samples
# 0.8917527
# Training loss (for one batch) at step 9010: 0.0617
# Seen so far: 144176 samples
# 0.891785

# %% [markdown]
# **Error**
# 1. ResourceExhaustedError: failed to allocate memory [Op:Mul]
#  > 해결: 인터넷 캐시 지움
#  밑에 방법은 해결을 하지 못했다.
#
# 2. Kernel Restarting
# The kernel appears to have died. It will restart automatically.
#  > 해결: 배치 사이즈 바꿈
#  거진 6시간 돌렸더니 에러떠서 다시 돌리는 중..
#  95% 정확도까지 올라갔다.

# %% [raw]
# # tf.keras.backend.clear_session()
#
# # gpus = tf.config.experimental.list_physical_devices('GPU')
# # if gpus:
# #     try:
# #         # 필요할 때 메모리를 증가시키도록 설정
# #         for gpu in gpus:
# #             tf.config.experimental.set_memory_growth(gpu, True)
# #     except RuntimeError as e:
# #         # 프로그램 시작시에 메모리 증가가 설정되어야만 합니다
# #         print(e)
#
# # !nvidia-smi

# %% [markdown]
# ### 모델 테스트

# %%
test_path = "/aiffel/aiffel/vnfoods/data/30vnfoods/Test"

test_ds = load_data(data_path=test_path)

for step_train, (x_batch_train, y_batch_train) in enumerate(test_ds.take(10)):
    prediction = model(x_batch_train)
    print("{}/{}".format(np.array(tf.equal(tf.argmax(y_batch_train, axis=1), tf.argmax(prediction, axis=1))).sum(), tf.argmax(y_batch_train, axis=1).shape[0]))
